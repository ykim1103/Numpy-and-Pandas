# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

import matplotlib.font_manager as fm            # 폰트 지정방법
font_name=fm.FontProperties(fname='C:\\Windows\\Fonts\\malgun.ttf').get_name()     
plt.rc('font',family=font_name)


mpl.rcParams['axes.unicode_minus']=False

# %%
youtube=pd.read_csv('info/1.백종원_info.csv',encoding="utf-8")
youtube

df=pd.DataFrame(youtube)
df


tmp3 = []
for i in df['view'].values:
    tmp=i.split("만회")[0]
    tmp2=int(tmp)
    tmp3.append(tmp2*10000)

    
print(tmp3)
df['view']=tmp3
print(type(tmp3[0]))

a=df['view'].sum()
print(a)
sum_list = []
sum_list.append(a)



#df.loc['cosum',:]=df.sum()     #열의 합계
#df
# Out:
# [25, 88, 51, 22, 22, 45, 53, 110, 36, 29, 155, 35, 85, 63, 144, 89, 102, 30, 51, 56]
# <class 'int'>
# 1291
#     Unnamed: 0                                              name  \
# 0            0                            [Sub] 스팸+달걀+김치+마요네즈=끝!
# 1            1            [Sub] 정말 '크리미'해요. 집에서 간단하게 색다른 오므라이스!!
# 2            2                      [ENG] 고구마빠스! 손에 묻지 않는 고구마맛탕!
# 3            3                             [ENG] 정말 쉽게 만드는 짜장 덮밥
# 4            4                   [ENG] 아삭아삭 고구마로 비빔밥을! 이거 말이 돼요.
# 5            5                    [ENG] 직접 만든 짜장소스로 짜장떡볶이를 간단하게~
# 6            6                     [ENG] 양파와 카레만 있으면 끝! 쉽고 맛있어요.
# 7            7                        [ENG] 비빔라면의 신세계! '김라면' 입니다
# 8            8                         [ENG] 집에서 먹는 신림동st 백순대볶음!
# 9            9                          [ENG] 시원하게 맛있는 장아찌소스 냉국수
# 10          10                [ENG] 무엇이든 다 어울리는 '만능 장아찌 소스' 만들기!
# 11          11                   [ENG] '깍두기 볶음밥' 등심집에서 볶아주는 그 맛!
# ...

# %%
# Out:
#     Unnamed: 0                                              name  \
# 0            0                            [Sub] 스팸+달걀+김치+마요네즈=끝!
# 1            1            [Sub] 정말 '크리미'해요. 집에서 간단하게 색다른 오므라이스!!
# 2            2                      [ENG] 고구마빠스! 손에 묻지 않는 고구마맛탕!
# 3            3                             [ENG] 정말 쉽게 만드는 짜장 덮밥
# 4            4                   [ENG] 아삭아삭 고구마로 비빔밥을! 이거 말이 돼요.
# 5            5                    [ENG] 직접 만든 짜장소스로 짜장떡볶이를 간단하게~
# 6            6                     [ENG] 양파와 카레만 있으면 끝! 쉽고 맛있어요.
# 7            7                        [ENG] 비빔라면의 신세계! '김라면' 입니다
# 8            8                         [ENG] 집에서 먹는 신림동st 백순대볶음!
# 9            9                          [ENG] 시원하게 맛있는 장아찌소스 냉국수
# 10          10                [ENG] 무엇이든 다 어울리는 '만능 장아찌 소스' 만들기!
# 11          11                   [ENG] '깍두기 볶음밥' 등심집에서 볶아주는 그 맛!
# 12          12                    [ENG] 감자채전의 색다른 버전! '새둥지전'입니다.
# ...

# %%
youtube=pd.read_csv('info/1.백종원_info.csv',encoding="utf-8")
youtube

df=pd.DataFrame(youtube)
df


df.sum()
df.sum(axis=0)
df.loc['cosum',:]=df[['view']].sum()     #열의 합계
df
# Out:
#        Unnamed: 0                                              name  \
# 0             0.0                            [Sub] 스팸+달걀+김치+마요네즈=끝!
# 1             1.0            [Sub] 정말 '크리미'해요. 집에서 간단하게 색다른 오므라이스!!
# 2             2.0                      [ENG] 고구마빠스! 손에 묻지 않는 고구마맛탕!
# 3             3.0                             [ENG] 정말 쉽게 만드는 짜장 덮밥
# 4             4.0                   [ENG] 아삭아삭 고구마로 비빔밥을! 이거 말이 돼요.
# 5             5.0                    [ENG] 직접 만든 짜장소스로 짜장떡볶이를 간단하게~
# 6             6.0                     [ENG] 양파와 카레만 있으면 끝! 쉽고 맛있어요.
# 7             7.0                        [ENG] 비빔라면의 신세계! '김라면' 입니다
# 8             8.0                         [ENG] 집에서 먹는 신림동st 백순대볶음!
# 9             9.0                          [ENG] 시원하게 맛있는 장아찌소스 냉국수
# 10           10.0                [ENG] 무엇이든 다 어울리는 '만능 장아찌 소스' 만들기!
# 11           11.0                   [ENG] '깍두기 볶음밥' 등심집에서 볶아주는 그 맛!
# 12           12.0                    [ENG] 감자채전의 색다른 버전! '새둥지전'입니다.
# ...

# %%
del cctv_seoul['thumbnail']
cctv_seoul
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'thumbnail'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-c4bafa790c85> in <module>
# ----> 1 del cctv_seoul['thumbnail']
# ...

# %%
# Out:
#     Unnamed: 0                                               name  view  \
# 0            0  태풍 온 날 무인도에서 24시간 생!존!먹!방!😱(feat. 탈to the출)..[2화]  17만회
# 1            1                  SUB)태풍오는무인도에서 자급자족 생존먹방.. 🌊  [1화]  34만회
# 2            2     SUB)60인분 통돼지 한마리 🐖 바베큐 먹방!! 농촌라이프 ★첫 게스트s★등!장!  62만회
# 3            3  SUB)슬기네집 비번털렸습니다.. 입술도 털림.. 이런것좀 보내지마세요.. (fea...  48만회
# 4            4  비오는 날 ☔한우로 소고기 한!상!가!득! 푸짐하게 먹는날~ 소고기먹방 Korean...  38만회
# 5            5  SUB)가마솥 수!제!해!물!짜장면🍜 한~가득 농촌 먹방🎵 BLACK BEAN NO...  52만회
# 6            6  SUB)37kg대왕문어틈새라면 통먹방 Giant Octopus 82lb SEAFOO...  75만회
# 7            7                         SUB)배 터질때까지 배달음식 랜덤으로 시켜먹기  57만회
# 8            8  실비김치와 얼~큰하게 끓인 너구리3봉지 역대급 초밥먹방 ASMR  Sushi & S...  40만회
# 9            9  대창과 실비김치 비빔면 10인분만 간단하게 먹방 SPICY NOODLES & BEE...  63만회
# 10          10  SUB)가마솥뚜껑에 닭갈비 20인분 먹방 Stir fried spicy chicke...  37만회
# 11          11  SUB)치즈돈까스와 매콤한 쫄면 국룰조합 먹방 Pork cutlet & Jjolmy...  44만회
# ...

# %%
# Out:
#     Unnamed: 0                                               name  view  \
# 0            0  태풍 온 날 무인도에서 24시간 생!존!먹!방!😱(feat. 탈to the출)..[2화]  17만회
# 1            1                  SUB)태풍오는무인도에서 자급자족 생존먹방.. 🌊  [1화]  34만회
# 2            2     SUB)60인분 통돼지 한마리 🐖 바베큐 먹방!! 농촌라이프 ★첫 게스트s★등!장!  62만회
# 3            3  SUB)슬기네집 비번털렸습니다.. 입술도 털림.. 이런것좀 보내지마세요.. (fea...  48만회
# 4            4  비오는 날 ☔한우로 소고기 한!상!가!득! 푸짐하게 먹는날~ 소고기먹방 Korean...  38만회
# 5            5  SUB)가마솥 수!제!해!물!짜장면🍜 한~가득 농촌 먹방🎵 BLACK BEAN NO...  52만회
# 6            6  SUB)37kg대왕문어틈새라면 통먹방 Giant Octopus 82lb SEAFOO...  75만회
# 7            7                         SUB)배 터질때까지 배달음식 랜덤으로 시켜먹기  57만회
# 8            8  실비김치와 얼~큰하게 끓인 너구리3봉지 역대급 초밥먹방 ASMR  Sushi & S...  40만회
# 9            9  대창과 실비김치 비빔면 10인분만 간단하게 먹방 SPICY NOODLES & BEE...  63만회
# 10          10  SUB)가마솥뚜껑에 닭갈비 20인분 먹방 Stir fried spicy chicke...  37만회
# 11          11  SUB)치즈돈까스와 매콤한 쫄면 국룰조합 먹방 Pork cutlet & Jjolmy...  44만회
# ...
