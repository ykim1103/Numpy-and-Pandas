# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

import matplotlib.font_manager as fm            # 폰트 지정방법
font_name=fm.FontProperties(fname='C:\\Windows\\Fonts\\malgun.ttf').get_name()     
plt.rc('font',family=font_name)


mpl.rcParams['axes.unicode_minus']=False

# %%
import glob

# %%
file_list=glob.glob('C:\\Users\\ZENBOOK\\20명 푸드쿠킹\\info\\*.csv')
file_list
#print(type(file_list))
# Out:
# ['C:\\Users\\ZENBOOK\\20명 푸드쿠킹\\info\\01.백종원_info.csv',
#  'C:\\Users\\ZENBOOK\\20명 푸드쿠킹\\info\\02.떵개떵_info.csv',
#  'C:\\Users\\ZENBOOK\\20명 푸드쿠킹\\info\\03.문복희_info.csv',
#  'C:\\Users\\ZENBOOK\\20명 푸드쿠킹\\info\\04.하루한끼_info.csv',
#  'C:\\Users\\ZENBOOK\\20명 푸드쿠킹\\info\\05.햄지_info.csv',
#  'C:\\Users\\ZENBOOK\\20명 푸드쿠킹\\info\\06.쿠킹트리_info.csv',
#  'C:\\Users\\ZENBOOK\\20명 푸드쿠킹\\info\\07.FRAN_info.csv',
#  'C:\\Users\\ZENBOOK\\20명 푸드쿠킹\\info\\08.쯔양_info.csv',
#  'C:\\Users\\ZENBOOK\\20명 푸드쿠킹\\info\\09.유디티_info.csv',
#  'C:\\Users\\ZENBOOK\\20명 푸드쿠킹\\info\\10.한세_info.csv',
#  'C:\\Users\\ZENBOOK\\20명 푸드쿠킹\\info\\11.푸메_info.csv',
#  'C:\\Users\\ZENBOOK\\20명 푸드쿠킹\\info\\12.꿀키_info.csv',
#  'C:\\Users\\ZENBOOK\\20명 푸드쿠킹\\info\\13.MINEE EATS_info.csv',
#  'C:\\Users\\ZENBOOK\\20명 푸드쿠킹\\info\\14.엠브로_info.csv',
#  'C:\\Users\\ZENBOOK\\20명 푸드쿠킹\\info\\15.나름_info.csv',
#  'C:\\Users\\ZENBOOK\\20명 푸드쿠킹\\info\\16.아리키친_info.csv',
#  'C:\\Users\\ZENBOOK\\20명 푸드쿠킹\\info\\17.애주가_info.csv',
#  'C:\\Users\\ZENBOOK\\20명 푸드쿠킹\\info\\18.SOF_info.csv',
#  'C:\\Users\\ZENBOOK\\20명 푸드쿠킹\\info\\19.입짧은햇님_info.csv',
#  'C:\\Users\\ZENBOOK\\20명 푸드쿠킹\\info\\20.상윤쓰_info.csv',
#  'C:\\Users\\ZENBOOK\\20명 푸드쿠킹\\info\\21.야식이_info.csv',
#  'C:\\Users\\ZENBOOK\\20명 푸드쿠킹\\info\\22.산적TV_info.csv',
#  'C:\\Users\\ZENBOOK\\20명 푸드쿠킹\\info\\23.아내의식탁_info.csv',
#  'C:\\Users\\ZENBOOK\\20명 푸드쿠킹\\info\\24.권회훈_info.csv',
#  'C:\\Users\\ZENBOOK\\20명 푸드쿠킹\\info\\25.수빙수_info.csv',
#  'C:\\Users\\ZENBOOK\\20명 푸드쿠킹\\info\\26.먹어볼래_info.csv',
#  'C:\\Users\\ZENBOOK\\20명 푸드쿠킹\\info\\27.신쿡_info.csv',
#  'C:\\Users\\ZENBOOK\\20명 푸드쿠킹\\info\\28.가르마_info.csv',
#  'C:\\Users\\ZENBOOK\\20명 푸드쿠킹\\info\\29.시니_info.csv',
#  'C:\\Users\\ZENBOOK\\20명 푸드쿠킹\\info\\30.맛상무_info.csv']

# %%
for i in file_list:
    print(i)
    #print(type(i)) 
    youtuber=pd.read_csv(i, encoding='cp949')
    
# print(type(i))
# Out:
# C:\Users\ZENBOOK\20명 푸드쿠킹\info\01.백종원_info.csv
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-57-5723f8c6cd84> in <module>
#       2     print(i)
#       3     #print(type(i))
# ----> 4     youtuber=pd.read_csv(i, encoding='cp949')
#       5
#       6 # print(type(i))
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
#     677
#     678     parser_f.__name__ = name
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     446
#     447     # Create the parser.
# --> 448     parser = TextFileReader(fp_or_buf, **kwds)
#     449
#     450     if chunksize or iterator:
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     878             self.options["has_index_names"] = kwds["has_index_names"]
#     879
# --> 880         self._make_engine(self.engine)
#     881
#     882     def close(self):
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1112     def _make_engine(self, engine="c"):
#    1113         if engine == "c":
# -> 1114             self._engine = CParserWrapper(self.f, **self.options)
#    1115         else:
#    1116             if engine == "python":
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1889         kwds["usecols"] = self.usecols
#    1890
# -> 1891         self._reader = parsers.TextReader(src, **kwds)
#    1892         self.unnamed_cols = self._reader.unnamed_cols
#    1893
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._get_header()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._tokenize_rows()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.raise_parser_error()
#
# UnicodeDecodeError: 'cp949' codec can't decode byte 0xbf in position 2: illegal multibyte sequence

# %%
for i in file_list:
    youtuber=pd.read_csv(i)
youtuber
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._string_convert()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers._string_box_utf8()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xb9 in position 0: invalid start byte
#
# During handling of the above exception, another exception occurred:
#
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-55-e16164e8696a> in <module>
#       1 for i in file_list:
# ----> 2     youtuber=pd.read_csv(i)
#       3 youtuber
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
#     677
#     678     parser_f.__name__ = name
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     452
#     453     try:
# --> 454         data = parser.read(nrows)
#     455     finally:
#     456         parser.close()
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in read(self, nrows)
#    1131     def read(self, nrows=None):
#    1132         nrows = _validate_integer("nrows", nrows)
# -> 1133         ret = self._engine.read(nrows)
#    1134
#    1135         # May alter columns / col_dict
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in read(self, nrows)
#    2035     def read(self, nrows=None):
#    2036         try:
# -> 2037             data = self._reader.read(nrows)
#    2038         except StopIteration:
#    2039             if self._first_chunk:
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.read()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._read_low_memory()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_column_data()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._string_convert()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers._string_box_utf8()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xb9 in position 0: invalid start byte

# %%
for i in file_list:
    youtuber=pd,read_csv(i)
    #youtube=pd.read_csv('C:\\Users\\ZENBOOK\\20명 푸드쿠킹\\info\\01.백종원_info.csv')

    #조회수 '만회'제거하고 정수형태로 바꾸기
    view1 = []
    for i in youtube['view'].values:
        tmp=i.split("만회")[0]
        tmp2=int(tmp)
        view1.append(tmp2*10000)

        youtube['view']=view1


    # 댓글개수
    comment1=[]
    for i in youtube['comment']:
        i = (i.split(' ')[1].split('개')[0])
        if ',' in i:
            i = i.split(',')[0]+i.split(',')[1]
    
        comment1.append(int(i))    
    
    youtube['comment']=comment1


    # 좋아요개수
    like1=[]
    for i in youtube['likes_num']:
        if '천개' in i:
            a=float(i.split('천개')[0])*1000
            like1.append(int(a))
            
        else :
            b=float(i.split('만개')[0])*10000
            like1.append(int(b))

    youtube['likes_num']=like1



    # 싫어요 개수
    unlike1=[]
    for i in youtube['unlikes_num'].values:
        unlike_tmp=int(i.split('개')[0])
        unlike1.append(unlike_tmp)
        #print(unlike_tmp)
    youtube['unlikes_num']=unlike1
  
    
    
    # 영상길이
    time = []
    for i in youtube['time_duration']:
        a=int(i.split('\n')[1].split(':')[0])
        b= int(i.split('\n')[1].split(':')[1])
        time.append((60*a)+b)
    youtube['time_duration']= time




    sum_avg = {
         '조회수합' : youtube['view'].sum(axis=0),
         '조회수평균' : youtube['view'].mean(),

         '댓글수합' : youtube['comment'].sum(axis=0),
         '댓글수평균' : youtube['comment'].mean(),

         '좋아요합' : youtube['likes_num'].sum(axis=0),
         '좋아요평균' : youtube['likes_num'].mean(),

         '싫어요합' : youtube['unlikes_num'].sum(axis=0),
         '싫어요평균' : youtube['unlikes_num'].mean(),

         '영상길이합' : youtube['time_duration'].sum(axis=0),
         '영상길이평균' : youtube['time_duration'].mean()
    }

    youtube2=pd.DataFrame(sum_avg,index=['백종원'])
    youtube2
# Out:
#     Unnamed: 0                                              name  \
# 0            0                            [Sub] 스팸+달걀+김치+마요네즈=끝!
# 1            1            [Sub] 정말 '크리미'해요. 집에서 간단하게 색다른 오므라이스!!
# 2            2                      [ENG] 고구마빠스! 손에 묻지 않는 고구마맛탕!
# 3            3                             [ENG] 정말 쉽게 만드는 짜장 덮밥
# 4            4                   [ENG] 아삭아삭 고구마로 비빔밥을! 이거 말이 돼요.
# 5            5                    [ENG] 직접 만든 짜장소스로 짜장떡볶이를 간단하게~
# 6            6                     [ENG] 양파와 카레만 있으면 끝! 쉽고 맛있어요.
# 7            7                        [ENG] 비빔라면의 신세계! '김라면' 입니다
# 8            8                         [ENG] 집에서 먹는 신림동st 백순대볶음!
# 9            9                          [ENG] 시원하게 맛있는 장아찌소스 냉국수
# 10          10                [ENG] 무엇이든 다 어울리는 '만능 장아찌 소스' 만들기!
# 11          11                   [ENG] '깍두기 볶음밥' 등심집에서 볶아주는 그 맛!
# 12          12                    [ENG] 감자채전의 색다른 버전! '새둥지전'입니다.
# 13          13  [ENG] Make some '파개장'! Real 맛있어요. 대파농가 Cheer up!
# 14          14                          대파 듬뿍! 삼겹살로 만든 '대파 제육볶음'
# 15          15                               깍두기 담그는 법, 어렵지 않아요.
# 16          16                                소시지케찹볶음.. 이건 퍼펙트예요
# 17          17                               김밥으로 볶음밥! 넣고 볶으면 끝!
# 18          18                                  멕시코에는 없는 멕시칸 샐러드
# 19          19                           CU 백종원 도시락을 더 맛있게 먹는 방법
#
#                                             thumbnail     view previous_time  \
# 0   https://i.ytimg.com/vi/kj2ZupQ7fts/hqdefault.j...   250000        20시간 전
# 1   https://i.ytimg.com/vi/AlK2Gl6kHZI/hqdefault.j...   880000          1주 전
# 2   https://i.ytimg.com/vi/aXJgN_JjYDg/hqdefault.j...   510000          1주 전
# 3   https://i.ytimg.com/vi/_O4tvQtZDiU/hqdefault.j...   220000          1주 전
# 4   https://i.ytimg.com/vi/-bewV9LQ_JU/hqdefault.j...   220000          2주 전
# 5   https://i.ytimg.com/vi/7S9VN54ldnU/hqdefault.j...   450000          2주 전
# 6   https://i.ytimg.com/vi/rgKIUQgzhbs/hqdefault.j...   530000          2주 전
# 7   https://i.ytimg.com/vi/NvoCWyO0Vfg/hqdefault.j...  1100000          3주 전
# 19  http://www.youtube.com/watch?v=sw2YbfPbHk0  2020. 4. 14.      845
#
#     likes_num  unlikes_num  time_duration
# 0        7000           91            559
# 1       15000          299           1024
# 2       10000          165            764
# 3        3700           65            342
# 4        4300           97            798
# 5        8100          171            943
# 6        9600          136            604
# 7       17000          316            639
# 8        5900          101            726
# 9        5500          116            680
# 10      28000          985           1018
# 11       6100          118            910
# 12      14000          361            713
# 13      11000          213            892
# 14      22000          517            604
# 15      15000          468            893
# 16      17000          307            665
# 17       4700           87            359
# 18       7900          152            459
# 19       7500          193            379

# %%
youtube=pd.read_csv('C:\\Users\\ZENBOOK\\20명 푸드쿠킹\\info\\02.떵개떵_info.csv')

#조회수 '만회'제거하고 정수형태로 바꾸기
view1 = []
for i in youtube['view'].values:
    tmp=i.split("만회")[0]
    tmp2=int(tmp)
    view1.append(tmp2*10000)

    youtube['view']=view1


# 댓글개수
comment1=[]
for i in youtube['comment']:
    i = (i.split(' ')[1].split('개')[0])
    if ',' in i:
        i = i.split(',')[0]+i.split(',')[1]
    
    comment1.append(int(i))    
    
youtube['comment']=comment1


# 좋아요개수
like1=[]
for i in youtube['likes_num']:
    if '천개' in i:
        a=float(i.split('천개')[0])*1000
        like1.append(int(a))
            
    else :
        b=float(i.split('만개')[0])*10000
        like1.append(int(b))

youtube['likes_num']=like1



# 싫어요 개수
unlike1=[]
for i in youtube['unlikes_num'].values:
    unlike_tmp=int(i.split('개')[0])
    unlike1.append(unlike_tmp)
    #print(unlike_tmp)
youtube['unlikes_num']=unlike1
  
    
    
# 영상길이
time = []
for i in youtube['time_duration']:
    a=int(i.split('\n')[1].split(':')[0])
    b= int(i.split('\n')[1].split(':')[1])
    time.append((60*a)+b)
youtube['time_duration']= time




sum_avg = {
     '조회수합' : youtube['view'].sum(axis=0),
     '조회수평균' : youtube['view'].mean(),

     '댓글수합' : youtube['comment'].sum(axis=0),
     '댓글수평균' : youtube['comment'].mean(),

     '좋아요합' : youtube['likes_num'].sum(axis=0),
     '좋아요평균' : youtube['likes_num'].mean(),

     '싫어요합' : youtube['unlikes_num'].sum(axis=0),
     '싫어요평균' : youtube['unlikes_num'].mean(),

     '영상길이합' : youtube['time_duration'].sum(axis=0),
     '영상길이평균' : youtube['time_duration'].mean()
}

youtube2=pd.DataFrame(sum_avg,index=['떵개떵'])
youtube2
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._string_convert()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers._string_box_utf8()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xb9 in position 0: invalid start byte
#
# During handling of the above exception, another exception occurred:
#
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-13-be1a7d4d0948> in <module>
# ----> 1 youtube=pd.read_csv('C:\\Users\\ZENBOOK\\20명 푸드쿠킹\\info\\02.떵개떵_info.csv')
#       2
#       3 #조회수 '만회'제거하고 정수형태로 바꾸기
#       4 view1 = []
#       5 for i in youtube['view'].values:
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
#     677
#     678     parser_f.__name__ = name
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     452
#     453     try:
# --> 454         data = parser.read(nrows)
#     455     finally:
#     456         parser.close()
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in read(self, nrows)
#    1131     def read(self, nrows=None):
#    1132         nrows = _validate_integer("nrows", nrows)
# -> 1133         ret = self._engine.read(nrows)
#    1134
#    1135         # May alter columns / col_dict
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in read(self, nrows)
#    2035     def read(self, nrows=None):
#    2036         try:
# -> 2037             data = self._reader.read(nrows)
#    2038         except StopIteration:
#    2039             if self._first_chunk:
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.read()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._read_low_memory()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_column_data()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._string_convert()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers._string_box_utf8()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xb9 in position 0: invalid start byte

# %%
litt = ['C:\\Users\\ZENBOOK\\20명 푸드쿠킹\\info\\01.백종원_info.csv',2
for i in litt:
        pd.read_csv(i)
        
        
        
        
        
#youtube2=pd.DataFrame(sum_avg,index=['떵개떵'])
#youtube2
